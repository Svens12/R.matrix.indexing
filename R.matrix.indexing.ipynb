# %%
A<-matrix(c(2,3,4,0,1,2,-1,-2,5,8,6,-3),nrow=4,ncol=3,byrow=TRUE)
A
# Out:
#      [,1] [,2] [,3]
# [1,]  2    3    4
# [2,]  0    1    2
# [3,] -1   -2    5
# [4,]  8    6   -3

# %%
A[1,2]
# Out:
# [1] 3

# %%
A[1,]
# Out:
# [1] 2 3 4

# %%
A[1]
# Out:
# [1] 2

# %%
A[3,]
# Out:
# [1] -1 -2  5

# %%
A[,2]
# Out:
# [1]  3  1 -2  6

# %%
A[nrow(A),]
# Out:
# [1]  8  6 -3

# %%
A[,ncol(A)]
# Out:
# [1]  4  2  5 -3

# %%
A[-3,]
# Out:
#      [,1] [,2] [,3]
# [1,] 2    3     4
# [2,] 0    1     2
# [3,] 8    6    -3

# %%
A[,-1]
# Out:
#      [,1] [,2]
# [1,]  3    4
# [2,]  1    2
# [3,] -2    5
# [4,]  6   -3

# %%
A<-matrix(c(2,3,4,0,1,2,-1,-2,5,8,6,-3),nrow=4,ncol=3,byrow=TRUE)
A[2,3]=9

# %%
A
# Out:
#      [,1] [,2] [,3]
# [1,]  2    3    4
# [2,]  0    1    9
# [3,] -1   -2    5
# [4,]  8    6   -3

# %%
A[1:3,1:2]
# Out:
#      [,1] [,2]
# [1,]  2    3
# [2,]  0    1
# [3,] -1   -2

# %%
A[1:3,-2]
# Out:
#      [,1] [,2]
# [1,]  2   4
# [2,]  0   9
# [3,] -1   5

# %%
A[-3,2:3]
# Out:
#      [,1] [,2]
# [1,] 3     4
# [2,] 1     9
# [3,] 6    -3

# %%
A[c(1,3),]
# Out:
#      [,1] [,2] [,3]
# [1,]  2    3   4
# [2,] -1   -2   5

# %%
A[,c(1,3)]
# Out:
#      [,1] [,2]
# [1,]  2    4
# [2,]  0    9
# [3,] -1    5
# [4,]  8   -3

# %%
A<-matrix(c(2,3,4,0,1,2,-1,-2,5,8,6,-3),nrow=4,ncol=3,byrow=TRUE)

A
# Out:
#      [,1] [,2] [,3]
# [1,]  2    3    4
# [2,]  0    1    2
# [3,] -1   -2    5
# [4,]  8    6   -3

# %%
A=A[,-2]
A
# Out:
#      [,1] [,2]
# [1,]  2    4
# [2,]  0    2
# [3,] -1    5
# [4,]  8   -3

# %%
A=A[-3,]

# %%
A
# Out:
#      [,1] [,2]
# [1,] 2     4
# [2,] 0     2
# [3,] 8    -3

# %%
A<-matrix(c(2,3,4,0,1,2,-1,-2,5,8,6,-3),nrow=4,ncol=3,byrow=TRUE)
A
# Out:
#      [,1] [,2] [,3]
# [1,]  2    3    4
# [2,]  0    1    2
# [3,] -1   -2    5
# [4,]  8    6   -3

# %%
diag(A)
# Out:
# [1] 2 1 5
